# %% [markdown]
# # Plotting
#
# Lean the basics of plotting with `pandas` for *preliminary* visual eploraiton of data.
#
# ## Dataset 1: Glacial Data
# Import that hoe

# %%
import pandas as pd

# read in the file

df = pd.read_csv('glacial_loss.csv')

# view

df.head()
# Out:
#    year     europe      arctic     alaska       asia  north_america  \
# 0  1961  -5.128903 -108.382987 -18.721190 -32.350759     -14.359007
# 1  1962   5.576282 -173.252450 -24.324790  -4.675440      -2.161842
# 2  1963 -10.123105   -0.423751  -2.047567  -3.027298     -27.535881
# 3  1964  -4.508358   20.070148   0.477800 -18.675385      -2.248286
# 4  1965  10.629385   43.695389  -0.115332 -18.414602     -19.398765
#
#    south_america  antarctica  global_glacial_volume_change  \
# 0      -4.739367  -35.116389                   -220.823515
# 1     -13.694367  -78.222887                   -514.269862
# 2       3.419633    3.765109                   -550.575640
# 3      20.732633   14.853096                   -519.589859
# 4       6.862102   22.793484                   -473.112003
#
#    annual_sea_level_rise  cumulative_sea_level_rise
# 0               0.610010                   0.610010
# 1               0.810625                   1.420635
# ...

# %%
# print columns

df.columns
# Out:
# Index(['year', 'europe', 'arctic', 'alaska', 'asia', 'north_america',
#        'south_america', 'antarctica', 'global_glacial_volume_change',
#        'annual_sea_level_rise', 'cumulative_sea_level_rise'],
#       dtype='object')

# %% [markdown]
# # `plot()` method
# `pandas.DataFrame` has a built-in method `plot` for plotting
# Default behavior of plot without specifying parameters:
#
# - creates one line plot for each pf the columns
# -

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Line Plot
#
# We can make a line plot of one column against another by using the following syntax:
# ```
# df.plot(x='x_values_column', y='y_values_col')

# %%
# change in glacial volume per year in Europe
df.plot(x='year', y='europe')
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# Bais customization specificiny other arguments in `plot()`

# %%
df.plot(x='year',
        y='europe',
       title='Change in Glacial Volume per year in Europe',
       xlabel='Year',
       ylabel='Change in glacial vol (km3)',
        color = 'green')
# Out:
# <AxesSubplot:title={'center':'Change in Glacial Volume per year in Europe'}, xlabel='Year', ylabel='Change in glacial vol (km3)'>

# %% [markdown]
# # Multiple Line Plots
#
# - y: a list of column names that will be plotted
# - color: specificy the color of each column with a dictionary `{'col1':'color1','col2':'color2}'`

# %%
colors = {'arctic':'#F48FB1',
         'alaska':'purple'}

df.plot(x='year',
       y=['arctic','alaska'],
       color=colors)
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# Create separate plot setting the `subset` arguement to `true`

# %%
df.plot(x='year',
       y=['arctic','alaska'],
       color=colors,
       subplots=True)
# Out:
# array([<AxesSubplot:xlabel='year'>, <AxesSubplot:xlabel='year'>],
#       dtype=object)

# %% [markdown]
# ## Check-in
#
# 1) Plot annual sea lvl rise with respect to years
#
# 2) In the following code, what info is stored in the `columns` variable? Describe what we are plotting

# %%
columns = df.loc[:,'europe':'antarctica'].columns

df.plot(x='year',
       y='annual_sea_level_rise',
       subplots=True)
# Out:
# array([<AxesSubplot:xlabel='year'>], dtype=object)

# %%
columns = df.loc[:,'europe':'antarctica'].columns             # .columns makes sure only the column names are collected

df.plot(x='year',
       y=columns,
       subplots=True)
# Out:
# array([<AxesSubplot:xlabel='year'>, <AxesSubplot:xlabel='year'>,
#        <AxesSubplot:xlabel='year'>, <AxesSubplot:xlabel='year'>,
#        <AxesSubplot:xlabel='year'>, <AxesSubplot:xlabel='year'>,
#        <AxesSubplot:xlabel='year'>], dtype=object)

# %% [markdown]
# ## Palmer Penguins Dataset
# Reading in the dataset using a url

# %%
penguins = pd.read_csv('https://bit.ly/palmer-penguins-csv')

penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex  year
# 0       3750.0    male  2007
# 1       3800.0  female  2007
# 2       3250.0  female  2007
# 3          NaN     NaN  2007
# 4       3450.0  female  2007

# %% [markdown]
# # Preliminary Checks
# check data types and # of non NA values on each column

# %%
penguins.info()
# object is typically how strings are represented
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
#  7   year               344 non-null    int64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 21.6+ KB

# %% [markdown]
# # Simple stats about numeric columns

# %%
penguins.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000
#
#               year
# count   344.000000
# mean   2008.029070
# std       0.818356
# min    2007.000000
# 25%    2007.000000
# 50%    2008.000000
# 75%    2009.000000
# max    2009.000000

# %% [markdown]
# # Categorical Data Info

# %%
# for cat data and year, count unique vlaues

penguins[['species','island','sex','year']].nunique()
# Out:
# species    3
# island     3
# sex        2
# year       3
# dtype: int64

# %% [markdown]
# ## Unique values for a specific column

# %%
print(penguins.species.unique())
# Out:
# ['Adelie' 'Gentoo' 'Chinstrap']

# %% [markdown]
# ## Unique attribute value count

# %%
penguins.species.value_counts()
# Out:
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: species, dtype: int64

# %% [markdown]
# # `kind` argument in `plot()`

# %% [markdown]
# # Scatterplots
# Visually compare flipper length to body mass

# %%
penguins.plot(kind='scatter',
             x='flipper_length_mm',
             y='body_mass_g',
             alpha=0.4)
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %% [markdown]
# # Bar Plot
#
# set `kind ='bar'` in `plot`
#
# EX: Data about the 10 tinest penguins (lowest body mass)
#
# 1) Fubd pegnuins with the smallest bodies using `nsmallest()`

# %%
smallest = penguins.body_mass_g.nsmallest(10)

smallest
# Out:
# 314    2700.0
# 58     2850.0
# 64     2850.0
# 54     2900.0
# 98     2900.0
# 116    2900.0
# 298    2900.0
# 104    2925.0
# 47     2975.0
# 44     3000.0
# Name: body_mass_g, dtype: float64

# %%
smallest = penguins.body_mass_g.nsmallest(10).sort_values(ascending=False)

smallest
# Out:
# 44     3000.0
# 47     2975.0
# 104    2925.0
# 54     2900.0
# 98     2900.0
# 116    2900.0
# 298    2900.0
# 58     2850.0
# 64     2850.0
# 314    2700.0
# Name: body_mass_g, dtype: float64

# %%
#plotting 
# n smallest must be a series in order to be plotting using bar
smallest.plot(kind='bar',
             color='pink')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Assessing Other Attributes of Smallest
#
# `index` of the `smallest` series to select those rows in og penguins data frane using `loc`

# %%
penguins.loc[smallest.index]
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 44      Adelie      Dream            37.0           16.9              185.0
# 47      Adelie      Dream            37.5           18.9              179.0
# 104     Adelie     Biscoe            37.9           18.6              193.0
# 54      Adelie     Biscoe            34.5           18.1              187.0
# 98      Adelie      Dream            33.1           16.1              178.0
# 116     Adelie  Torgersen            38.6           17.0              188.0
# 298  Chinstrap      Dream            43.2           16.6              187.0
# 58      Adelie     Biscoe            36.5           16.6              181.0
# 64      Adelie     Biscoe            36.4           17.1              184.0
# 314  Chinstrap      Dream            46.9           16.6              192.0
#
#      body_mass_g     sex  year
# 44        3000.0  female  2007
# 47        2975.0     NaN  2007
# 104       2925.0  female  2009
# ...

# %% [markdown]
# # Histogram
#
# Set `kind = hist` in plot

# %%
penguins.plot(kind = 'hist')               # spits out everything
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# distribution of flipper length measurements
# first select data, then plot

penguins.flipper_length_mm.plot(kind = 'hist',
                               title='Penguin flipper length distribution',
                               xlabel= 'Flipper Length (mm)',
                               grid=True,
                               color='pink')
# Out:
# <AxesSubplot:title={'center':'Penguin flipper length distribution'}, ylabel='Frequency'>

# %% [markdown]
# ## Check in
#
# 1) Select bill_length_mm and bill_depth_mm
# 2) Update the kind parameter to 'box' to make boxplots for each
# 3) Select both rows and columns to create a histogram of flipper length of gentoo penguins

# %%
bill_length = penguins.bill_length_mm

bill_length.head()
# Out:
# 0    39.1
# 1    39.5
# 2    40.3
# 3     NaN
# 4    36.7
# Name: bill_length_mm, dtype: float64

# %%
bill_depth = penguins.bill_depth_mm

bill_depth.head()
# Out:
# 0    18.7
# 1    17.4
# 2    18.0
# 3     NaN
# 4    19.3
# Name: bill_depth_mm, dtype: float64

# %%
bill_length.plot(kind='box',
                color='pink')
# Out:
# <AxesSubplot:>

# %%
bill_depth.plot(kind='box',
                color='purple')
# Out:
# <AxesSubplot:>

# %%
boxpenguins = penguins[['bill_length_mm', 'bill_depth_mm']]

boxpenguins.plot(kind='box',
                color='hotpink')
# Out:
# <AxesSubplot:>

# %%
gentoo = penguins.loc[penguins.species == 'Gentoo', ['flipper_length_mm']]

gentoo.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>
